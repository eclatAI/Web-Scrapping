# %%
import pandas as pd
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
url_state='https://nursesalaryguide.net/nurse-salary-by-state/'

# %%
uClient = uReq(url_state)
page_html_state = uClient.read()

# %%
page_soup = soup(page_html_state, "html.parser")
tables_state = page_soup.findAll("table",{"class":"tablepress tablepress-id-1 tablepress-responsive"})

# %%
#url_cl='https://nursesalaryguide.net/registered-nurse-rn-salary/'

# %%
#uClient = uReq(url_cl)
#page_html_cl = uClient.read()

# %%
#page_soup = soup(page_html_cl, "html.parser")
#cl = page_soup.find_all("strong")

# %%
#cl

# %%
state=[]
hourly_salary=[]
monthly_salary=[]
for table in tables_state[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(list(row.find('td', class_='column-1').text.strip().split(' '))[-1])
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())

# %%
sheet1=pd.DataFrame(list(zip(state,hourly_salary,monthly_salary)), columns= ['State','Average Salary (Hourly)','Average Salary (Annual)'])

# %%
sheet1.head()
# Out:
#         State Average Salary (Hourly) Average Salary (Annual)
# 0     Alabama                  $28.96                 $60,230
# 1      Alaska                  $45.81                 $95,270
# 2     Arizona                  $38.64                 $80,380
# 3    Arkansas                  $30.60                 $63,640
# 4  California                  $57.96                $120,560

# %%
sheet1.to_csv('metro.csv')

# %%
Alabama = 'https://nursesalaryguide.net/nurse-salary-in-alabama'
Alaska = 'https://nursesalaryguide.net/nurse-salary-in-alaska/'
Arizona = 'https://nursesalaryguide.net/nurse-salary-in-arizona/'
Arkansas = 'https://nursesalaryguide.net/nurse-salary-in-arkansas/'
California = 'https://nursesalaryguide.net/nurse-salary-in-california/'
Colorado = 'https://nursesalaryguide.net/nurse-salary-in-colorado/'
Connecticut = 'https://nursesalaryguide.net/nurse-salary-in-connecticut/'
Delaware = 'https://nursesalaryguide.net/nurse-salary-in-delaware/'
District_of_Columbia = 'https://nursesalaryguide.net/nurse-salary-in-district-of-columbia/'
Florida = 'https://nursesalaryguide.net/nurse-salary-in-florida/'
Georgia = 'https://nursesalaryguide.net/nurse-salary-in-georgia/'
Hawaii = 'https://nursesalaryguide.net/nurse-salary-in-hawaii/'
Idaho = 'https://nursesalaryguide.net/nurse-salary-in-idaho/'
Illinois = 'https://nursesalaryguide.net/nurse-salary-in-illinois/'
Indiana = 'https://nursesalaryguide.net/nurse-salary-in-indiana/'
Iowa ='https://nursesalaryguide.net/nurse-salary-in-iowa/'
Kansas ='https://nursesalaryguide.net/nurse-salary-in-kansas/'
Kentucky ='https://nursesalaryguide.net/nurse-salary-in-kentucky/'
Louisiana ='https://nursesalaryguide.net/nurse-salary-in-louisiana/'
Maine ='https://nursesalaryguide.net/nurse-salary-in-maine/'
Maryland ='https://nursesalaryguide.net/nurse-salary-in-maryland/'
Massachusetts ='https://nursesalaryguide.net/nurse-salary-in-massachusetts/'
Michigan = 'https://nursesalaryguide.net/nurse-salary-in-michigan/'
Minnesota ='https://nursesalaryguide.net/nurse-salary-in-minnesota/'
Mississippi ='https://nursesalaryguide.net/nurse-salary-in-mississippi/'
Missouri ='https://nursesalaryguide.net/nurse-salary-in-missouri/'
Montana ='https://nursesalaryguide.net/nurse-salary-in-montana/'
Nebraska ='https://nursesalaryguide.net/nurse-salary-in-nebraska/'
Nevada ='https://nursesalaryguide.net/nurse-salary-in-nevada/'
New_Hampshire ='https://nursesalaryguide.net/nurse-salary-in-new-hampshire/'
New_Jersey ='https://nursesalaryguide.net/nurse-salary-in-new-jersey/'
New_Mexico ='https://nursesalaryguide.net/nurse-salary-in-new-mexico/'
New_York ='https://nursesalaryguide.net/nurse-salary-in-new-york/'
North_Carolina ='https://nursesalaryguide.net/nurse-salary-in-north-carolina/'
North_Dakota ='https://nursesalaryguide.net/nurse-salary-in-north-dakota/'
Ohio ='https://nursesalaryguide.net/nurse-salary-in-ohio/'
Oklahoma ='https://nursesalaryguide.net/nurse-salary-in-oklahoma/'
Oregon ='https://nursesalaryguide.net/nurse-salary-in-oregon/'
Pennsylvania ='https://nursesalaryguide.net/nurse-salary-in-pennsylvania/'
Puerto_Rico ='https://nursesalaryguide.net/nurse-salary-in-puerto-rico/'
South_Carolina ='https://nursesalaryguide.net/nurse-salary-in-south-carolina/'
South_Dakota ='https://nursesalaryguide.net/nurse-salary-in-south-dakota/'
Tennessee ='https://nursesalaryguide.net/nurse-salary-in-tennessee/'
Texas = 'https://nursesalaryguide.net/nurse-salary-in-texas/'
Utah = 'https://nursesalaryguide.net/nurse-salary-in-utah/'
Vermont = 'https://nursesalaryguide.net/nurse-salary-in-vermont/'
Virginia = 'https://nursesalaryguide.net/nurse-salary-in-virginia/'
Washington = 'https://nursesalaryguide.net/nurse-salary-in-washington/'
West_Virginia = 'https://nursesalaryguide.net/nurse-salary-in-west-virginia/'
Wisconsin = 'https://nursesalaryguide.net/nurse-salary-in-wisconsin/'
Wyoming = 'https://nursesalaryguide.net/nurse-salary-in-wyoming/'

# %%
state_lst = [Alabama ,
Alaska ,
Arizona ,
Arkansas ,
California ,
Colorado ,
Connecticut ,
Delaware ,
District_of_Columbia ,
Florida  ,
Georgia  ,
Hawaii  ,
Idaho  ,
Illinois ,
Indiana ,
Iowa ,
Kansas,
Kentucky,
Louisiana ,
Maine ,
Maryland,
Massachusetts ,
Michigan ,
Minnesota ,
Mississippi ,
Missouri ,
Montana,
Nebraska ,
Nevada ,
New_Hampshire ,
New_Jersey ,
New_Mexico ,
New_York ,
North_Carolina ,
North_Dakota ,
Ohio ,
Oklahoma ,
Oregon ,
Pennsylvania ,
Puerto_Rico ,
South_Carolina ,
South_Dakota ,
Tennessee ,
Texas ,
Utah ,
Vermont ,
Virginia ,
Washington ,
West_Virginia ,
Wisconsin ,
Wyoming ]

# %%
uClient = uReq(url_state)

# %%
uClient=[]
page_html=[]
for i in state_lst:
    uClient.append(uReq(i))

# %%
uClient[0]

# %%
page_html0 = uClient[0].read()
page_html1 = uClient[1].read()
page_html2 = uClient[2].read()
page_html3 = uClient[3].read()
page_html4 = uClient[4].read()
page_html5 = uClient[5].read()
page_html6 = uClient[6].read()
page_html7 = uClient[7].read()
page_html8 = uClient[8].read()
page_html9 = uClient[9].read()
page_html10 = uClient[10].read()
page_html11 = uClient[11].read()
page_html12 = uClient[12].read()
page_html13 = uClient[13].read()
page_html14 = uClient[14].read()
page_html15 = uClient[15].read()
page_html16 = uClient[16].read()
page_html17 = uClient[17].read()
page_html18 = uClient[18].read()
page_html19 = uClient[19].read()
page_html20 = uClient[20].read()
page_html21 = uClient[21].read()
page_html22 = uClient[22].read()
page_html23 = uClient[23].read()
page_html24 = uClient[24].read()
page_html25 = uClient[25].read()
page_html26 = uClient[26].read()
page_html27 = uClient[27].read()
page_html28 = uClient[28].read()
page_html29 = uClient[29].read()
page_html30 = uClient[30].read()
page_html31 = uClient[31].read()
page_html32 = uClient[32].read()
page_html33 = uClient[33].read()
page_html34 = uClient[34].read()
page_html35 = uClient[35].read()
page_html36 = uClient[36].read()
page_html37 = uClient[37].read()
page_html38 = uClient[38].read()
page_html39 = uClient[39].read()
page_html40 = uClient[40].read()
page_html41 = uClient[41].read()
page_html42 = uClient[42].read()
page_html43 = uClient[43].read()
page_html44 = uClient[44].read()
page_html45 = uClient[45].read()
page_html46 = uClient[46].read()
page_html47 = uClient[47].read()
page_html48 = uClient[48].read()
page_html49 = uClient[49].read()
page_html50 = uClient[50].read()

# %%
#page_soup=[]
#for i in page_html:
#    page_soup.append(soup(str(i), "html.parser"))

page_soup0=soup(page_html0,"html.parser")
page_soup1=soup(page_html1,"html.parser")
page_soup2=soup(page_html2,"html.parser")
page_soup3=soup(page_html3,"html.parser")
page_soup4=soup(page_html4,"html.parser")
page_soup5=soup(page_html5,"html.parser")
page_soup6=soup(page_html6,"html.parser")
page_soup7=soup(page_html7,"html.parser")
page_soup8=soup(page_html8,"html.parser")
page_soup9=soup(page_html9,"html.parser")
page_soup10=soup(page_html10,"html.parser")
page_soup11=soup(page_html11,"html.parser")
page_soup12=soup(page_html12,"html.parser")
page_soup13=soup(page_html13,"html.parser")
page_soup14=soup(page_html14,"html.parser")
page_soup15=soup(page_html15,"html.parser")
page_soup16=soup(page_html16,"html.parser")
page_soup17=soup(page_html17,"html.parser")
page_soup18=soup(page_html18,"html.parser")
page_soup19=soup(page_html19,"html.parser")
page_soup20=soup(page_html20,"html.parser")
page_soup21=soup(page_html21,"html.parser")
page_soup22=soup(page_html22,"html.parser")
page_soup23=soup(page_html23,"html.parser")
page_soup24=soup(page_html24,"html.parser")
page_soup25=soup(page_html25,"html.parser")
page_soup26=soup(page_html26,"html.parser")
page_soup27=soup(page_html27,"html.parser")
page_soup28=soup(page_html28,"html.parser")
page_soup29=soup(page_html29,"html.parser")
page_soup30=soup(page_html30,"html.parser")
page_soup31=soup(page_html31,"html.parser")
page_soup32=soup(page_html32,"html.parser")
page_soup33=soup(page_html33,"html.parser")
page_soup34=soup(page_html34,"html.parser")
page_soup35=soup(page_html35,"html.parser")
page_soup36=soup(page_html36,"html.parser")
page_soup37=soup(page_html37,"html.parser")
page_soup38=soup(page_html38,"html.parser")
page_soup39=soup(page_html39,"html.parser")
page_soup40=soup(page_html40,"html.parser")
page_soup41=soup(page_html41,"html.parser")
page_soup42=soup(page_html42,"html.parser")
page_soup43=soup(page_html43,"html.parser")
page_soup44=soup(page_html44,"html.parser")
page_soup45=soup(page_html45,"html.parser")
page_soup46=soup(page_html46,"html.parser")
page_soup47=soup(page_html47,"html.parser")
page_soup48=soup(page_html48,"html.parser")
page_soup49=soup(page_html49,"html.parser")
page_soup50=soup(page_html50,"html.parser")

# %%
tables0=(page_soup0.findAll("table",{"class":"tablepress tablepress-id-6 tablepress-responsive"}))
tables1=(page_soup1.findAll("table",{"class":"tablepress tablepress-id-9 tablepress-responsive"}))
tables2=(page_soup2.findAll("table",{"class":"tablepress tablepress-id-10 tablepress-responsive"}))
tables3=(page_soup3.findAll("table",{"class":"tablepress tablepress-id-13 tablepress-responsive"}))
tables4=(page_soup4.findAll("table",{"class":"tablepress tablepress-id-16 tablepress-responsive"}))
tables5=(page_soup5.findAll("table",{"class":"tablepress tablepress-id-33 tablepress-responsive"}))
tables6=(page_soup6.findAll("table",{"class":"tablepress tablepress-id-34 tablepress-responsive"}))
tables7=(page_soup7.findAll("table",{"class":"tablepress tablepress-id-36 tablepress-responsive"}))
tables8=(page_soup8.findAll("table",{"class":"tablepress tablepress-id-35 tablepress-responsive"}))
tables9=(page_soup9.findAll("table",{"class":"tablepress tablepress-id-37 tablepress-responsive"}))
tables10=(page_soup10.findAll("table",{"class":"tablepress tablepress-id-38 tablepress-responsive"}))
tables11=(page_soup11.findAll("table",{"class":"tablepress tablepress-id-39 tablepress-responsive"}))
tables12=(page_soup12.findAll("table",{"class":"tablepress tablepress-id-42 tablepress-responsive"}))
tables13=(page_soup13.findAll("table",{"class":"tablepress tablepress-id-45 tablepress-responsive"}))
tables14=(page_soup14.findAll("table",{"class":"tablepress tablepress-id-48 tablepress-responsive"}))
tables15=(page_soup15.findAll("table",{"class":"tablepress tablepress-id-51 tablepress-responsive"}))
tables16=(page_soup16.findAll("table",{"class":"tablepress tablepress-id-54 tablepress-responsive"}))
tables17=(page_soup17.findAll("table",{"class":"tablepress tablepress-id-57 tablepress-responsive"}))
tables18=(page_soup18.findAll("table",{"class":"tablepress tablepress-id-60 tablepress-responsive"}))
tables19=(page_soup19.findAll("table",{"class":"tablepress tablepress-id-63 tablepress-responsive"}))
tables20=(page_soup20.findAll("table",{"class":"tablepress tablepress-id-66 tablepress-responsive"}))
tables21=(page_soup21.findAll("table",{"class":"tablepress tablepress-id-67 tablepress-responsive"}))
tables22=(page_soup22.findAll("table",{"class":"tablepress tablepress-id-70 tablepress-responsive"}))
tables23=(page_soup23.findAll("table",{"class":"tablepress tablepress-id-73 tablepress-responsive"}))
tables24=(page_soup24.findAll("table",{"class":"tablepress tablepress-id-76 tablepress-responsive"}))
tables25=(page_soup25.findAll("table",{"class":"tablepress tablepress-id-79 tablepress-responsive"}))
tables26=(page_soup26.findAll("table",{"class":"tablepress tablepress-id-82 tablepress-responsive"}))
tables27=(page_soup27.findAll("table",{"class":"tablepress tablepress-id-85 tablepress-responsive"}))
tables28=(page_soup28.findAll("table",{"class":"tablepress tablepress-id-88 tablepress-responsive"}))
tables29=(page_soup29.findAll("table",{"class":"tablepress tablepress-id-91 tablepress-responsive"}))
tables30=(page_soup30.findAll("table",{"class":"tablepress tablepress-id-94 tablepress-responsive"}))
tables31=(page_soup31.findAll("table",{"class":"tablepress tablepress-id-97 tablepress-responsive"}))
tables32=(page_soup32.findAll("table",{"class":"tablepress tablepress-id-100 tablepress-responsive"}))
tables33=(page_soup33.findAll("table",{"class":"tablepress tablepress-id-103 tablepress-responsive"}))
tables34=(page_soup34.findAll("table",{"class":"tablepress tablepress-id-106 tablepress-responsive"}))
tables35=(page_soup35.findAll("table",{"class":"tablepress tablepress-id-109 tablepress-responsive"}))
tables36=(page_soup36.findAll("table",{"class":"tablepress tablepress-id-112 tablepress-responsive"}))
tables37=(page_soup37.findAll("table",{"class":"tablepress tablepress-id-115 tablepress-responsive"}))
tables38=(page_soup38.findAll("table",{"class":"tablepress tablepress-id-118 tablepress-responsive"}))
tables39=(page_soup39.findAll("table",{"class":"tablepress tablepress-id-121 tablepress-responsive"}))
tables40=(page_soup40.findAll("table",{"class":"tablepress tablepress-id-124 tablepress-responsive"}))
tables41=(page_soup41.findAll("table",{"class":"tablepress tablepress-id-127 tablepress-responsive"}))
tables42=(page_soup42.findAll("table",{"class":"tablepress tablepress-id-130 tablepress-responsive"}))
tables43=(page_soup43.findAll("table",{"class":"tablepress tablepress-id-133 tablepress-responsive"}))
tables44=(page_soup44.findAll("table",{"class":"tablepress tablepress-id-136 tablepress-responsive"}))
tables45=(page_soup45.findAll("table",{"class":"tablepress tablepress-id-139 tablepress-responsive"}))
tables46=(page_soup46.findAll("table",{"class":"tablepress tablepress-id-142 tablepress-responsive"}))
tables47=(page_soup47.findAll("table",{"class":"tablepress tablepress-id-145 tablepress-responsive"}))
tables48=(page_soup48.findAll("table",{"class":"tablepress tablepress-id-148 tablepress-responsive"}))
tables49=(page_soup49.findAll("table",{"class":"tablepress tablepress-id-151 tablepress-responsive"}))
tables50=(page_soup50.findAll("table",{"class":"tablepress tablepress-id-154 tablepress-responsive"}))

# %%
titles0 = page_soup0.find_all("title")
titles1 = page_soup1.find_all("title")
titles2 = page_soup2.find_all("title")
titles3 = page_soup3.find_all("title")
titles4 = page_soup4.find_all("title")
titles5 = page_soup5.find_all("title")
titles6 = page_soup6.find_all("title")
titles7 = page_soup7.find_all("title")
titles8 = page_soup8.find_all("title")
titles9 = page_soup9.find_all("title")
titles10 = page_soup10.find_all("title")
titles11 = page_soup11.find_all("title")
titles12 = page_soup12.find_all("title")
titles13 = page_soup13.find_all("title")
titles14 = page_soup14.find_all("title")
titles15 = page_soup15.find_all("title")
titles16 = page_soup16.find_all("title")
titles17 = page_soup17.find_all("title")
titles18 = page_soup18.find_all("title")
titles19 = page_soup19.find_all("title")
titles20 = page_soup20.find_all("title")
titles21 = page_soup21.find_all("title")
titles22 = page_soup22.find_all("title")
titles23 = page_soup23.find_all("title")
titles24 = page_soup24.find_all("title")
titles25 = page_soup25.find_all("title")
titles26 = page_soup26.find_all("title")
titles27 = page_soup27.find_all("title")
titles28 = page_soup28.find_all("title")
titles29 = page_soup29.find_all("title")
titles30 = page_soup30.find_all("title")
titles31 = page_soup31.find_all("title")
titles32 = page_soup32.find_all("title")
titles33 = page_soup33.find_all("title")
titles34 = page_soup34.find_all("title")
titles35 = page_soup35.find_all("title")
titles36 = page_soup36.find_all("title")
titles37 = page_soup37.find_all("title")
titles38 = page_soup38.find_all("title")
titles39 = page_soup39.find_all("title")
titles40 = page_soup40.find_all("title")
titles41 = page_soup41.find_all("title")
titles42 = page_soup42.find_all("title")
titles43 = page_soup43.find_all("title")
titles44 = page_soup44.find_all("title")
titles45 = page_soup45.find_all("title")
titles46 = page_soup46.find_all("title")
titles47 = page_soup47.find_all("title")
titles48 = page_soup48.find_all("title")
titles49 = page_soup49.find_all("title")
titles50 = page_soup50.find_all("title")

# %%
import statistics
state=[]
hourly_salary=[]
monthly_salary=[]
title=[]
hourly_median=[]
hourly_median_1=[]
monthly_median_1=[]
emp=[]

for table in tables0[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles0:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[0]:
                title=title[0]
hourly=[]
for i in hourly_salary:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary:
    monthly.append(i)
print(monthly)
inte=[]
for i in monthly:
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))
print(monthly_median_1)


n=len(hourly_salary)
for table in tables1[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles1:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[1]:
                title=title[1]
hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)
for table in tables2[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles2:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[2]:
                title=title[2]
hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)
for table in tables3[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles3:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[3]:
                title=title[3]
hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)
for table in tables4[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles4:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[4]:
                title=title[4]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)
for table in tables5[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles5:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[5]:
                title=title[5]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables6[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles6:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[6]:
                title=title[6]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)


for table in tables7[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles7:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[7]:
                title=title[7]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables8[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles8:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[8]:
                title=title[8]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables9[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles9:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[9]:
                title=title[9]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables10[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles10:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[10]:
                title=title[10]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables11[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles11:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[11]:
                title=title[11]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]

for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables12[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles12:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[12]:
                title=title[12]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables13[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles13:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[13]:
                title=title[13]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables14[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles14:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[14]:
                title=title[14]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables15[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles15:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[15]:
                title=title[15]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables16[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles16:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[16]:
                title=title[16]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables17[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles17:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[17]:
                title=title[17]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables18[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles18:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[18]:
                title=title[18]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables19[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles19:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[19]:
                title=title[19]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables20[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles20:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[20]:
                title=title[20]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables21[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles21:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[21]:
                title=title[21]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables22[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles22:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[22]:
                title=title[22]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables23[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles23:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[23]:
                title=title[23]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables24[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles24:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[24]:
                title=title[24]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables25[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles25:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[25]:
                title=title[25]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables26[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles26:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[26]:
                title=title[26]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables27[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles27:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[27]:
                title=title[27]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables28[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles28:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[28]:
                title=title[28]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables29[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles29:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[29]:
                title=title[29]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables30[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles30:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[30]:
                title=title[30]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables31[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles31:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[31]:
                title=title[31]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables32[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles32:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[32]:
                title=title[32]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables33[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles33:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[33]:
                title=title[33]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables34[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles34:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[34]:
                title=title[34]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables35[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles35:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[35]:
                title=title[35]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables36[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles36:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[36]:
                title=title[36]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables37[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles37:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[37]:
                title=title[37]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables38[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles38:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[38]:
                title=title[38]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables39[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles39:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[39]:
                title=title[39]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables40[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles40:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[40]:
                title=title[40]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables41[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles41:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[41]:
                title=title[41]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables42[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles42:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[42]:
                title=title[42]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables43[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles43:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[43]:
                title=title[43]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables44[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles44:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[44]:
                title=title[44]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables45[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles45:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[45]:
                title=title[45]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables46[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles46:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[46]:
                title=title[46]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables47[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles47:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[47]:
                title=title[47]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables48[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles48:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[48]:
                title=title[48]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables49[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles49:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[49]:
                title=title[49]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))

n=len(hourly_salary)

for table in tables50[0].find_all('tbody'):
    rows = table.find_all('tr')
    for row in rows:
        state.append(row.find('td', class_='column-1').text.strip())
        hourly_salary.append(row.find('td', class_='column-3').text.strip())
        monthly_salary.append(row.find('td', class_='column-4').text.strip())
        emp.append(row.find('td', class_='column-2').text.strip())
        for i in titles50:
            title.append(list(i.get_text().split(' '))[3])
            if state==state[50]:
                title=title[50]

hourly=[]
for i in hourly_salary[n:]:
    hourly.append(i)
print(hourly)
inte=[]
for i in hourly:
    if i=='-':
        continue
    inte.append(float(i[1:]))
print(inte)
hourly_median_1.append(statistics.median(inte))
print(hourly_median_1)

monthly=[]
for i in monthly_salary[n:]:
    monthly.append(i)
inte=[]
for i in monthly:
    if i=='-':
        continue
    inte.append(int(i[1:].replace(',','')))
print(inte)
monthly_median_1.append(statistics.median(inte))
# Out:
# ['$28.16', '$27.70', '$28.91', '$26.24', '$25.02', '$27.80', '$23.90', '$27.08', '$27.29', '$30.90', '$24.75', '$25.66', '$28.42', '$25.72', '$27.57']
# [28.16, 27.7, 28.91, 26.24, 25.02, 27.8, 23.9, 27.08, 27.29, 30.9, 24.75, 25.66, 28.42, 25.72, 27.57]
# [27.29]
# ['$58,560', '$57,620', '$60,120', '$54,580', '$52,040', '$57,830', '$49,710', '$56,330', '$56,760', '$64,260', '$51,480', '$53,380', '$59,120', '$53,500', '$57,350']
# [58560, 57620, 60120, 54580, 52040, 57830, 49710, 56330, 56760, 64260, 51480, 53380, 59120, 53500, 57350]
# [56760]
# ['$41.93', '$43.98', '$40.04', '$43.12']
# [41.93, 43.98, 40.04, 43.12]
# [27.29, 42.525]
# [87200, 91480, 83280, 89680]
# ['$35.92', '-', '$33.70', '$36.61', '$36.05', '$30.40', '$34.80', '$33.23']
# [35.92, 33.7, 36.61, 36.05, 30.4, 34.8, 33.23]
# [27.29, 42.525, 34.8]
# [74710, 70090, 76140, 74980, 63220, 72390, 69110]
# ['$26.13', '$27.48', '$27.23', '$30.25', '$25.91', '$29.50', '$26.67', '$25.69', '$27.81', '$27.17']
# ...

# %%
len(emp)
# Out:
# 583

# %%
len(monthly_median_1)
# Out:
# 51

# %%
sheet2=pd.DataFrame(list(zip(state,title,emp,hourly_salary,monthly_salary)), columns= ['City','State','Employment','Average Salary (Hourly)','Average Salary (Annual)'])

# %%
sheet2.head(20)
# Out:
#                                       City    State Employment  \
# 0             Anniston-Oxford-Jacksonville  Alabama      1,020
# 1                           Auburn-Opelika  Alabama        820
# 2                        Birmingham-Hoover  Alabama     17,640
# 3                    Daphne-Fairhope-Foley  Alabama      1,320
# 4                                  Decatur  Alabama        930
# 5                                   Dothan  Alabama      1,960
# 6                   Florence-Muscle Shoals  Alabama      1,460
# 7                               Huntsville  Alabama      5,010
# 8                                   Mobile  Alabama      5,120
# 9                               Montgomery  Alabama      3,650
# 10  Northeast Alabama nonmetropolitan area  Alabama      2,510
# 11  Northwest Alabama nonmetropolitan area  Alabama      1,360
# 12  Southeast Alabama nonmetropolitan area  Alabama      1,300
# 13  Southwest Alabama nonmetropolitan area  Alabama      1,330
# ...

# %%
lst10=[[' ']]
len(lst10)
# Out:
# 1

# %%
monthly_median_1.append(lst10)
monthly_median_1.append(lst10)
monthly_median_1.append(lst10)

# %%
hourly_median_1.append(lst10)
hourly_median_1.append(lst10)
hourly_median_1.append(lst10)

# %%
len(hourly_median_1)
# Out:
# 54

# %%
len(monthly_median_1)
# Out:
# 54

# %%
sheet1['Median Salary (Hourly)']=hourly_median_1

# %%
sheet1['Median Salary (Annual)']=monthly_median_1

# %%
sheet1.head()
# Out:
#         State Average Salary (Hourly) Average Salary (Annual)  \
# 0     Alabama                  $28.96                 $60,230
# 1      Alaska                  $45.81                 $95,270
# 2     Arizona                  $38.64                 $80,380
# 3    Arkansas                  $30.60                 $63,640
# 4  California                  $57.96                $120,560
#
#   Median Salary (Hourly) Median Salary (Annual)
# 0                  27.29                  56760
# 1                 42.525                88440.0
# 2                   34.8                  72390
# 3                   27.2                56570.0
# 4                  47.44                  98660

# %%
sheet1.to_csv('StateRN.csv')

# %%
sheet2.to_csv('MetroRN.csv')
